# %% [markdown]
# # Prepare Chicago Crime Data for a GitHub Repository

# %% [markdown]
# - Original Notebook Source: https://github.com/coding-dojo-data-science/preparing-chicago-crime-data
# - Updated 11/17/22

# %% [markdown]
# >- This notebook will process a "Crimes - 2001 to Preset.csv" crime file in your Downloads folder and save it as smaller .csv's in a new "Data/Chicago/" folder inside this notebook's folder/repo.

# %% [markdown]
# # INSTRUCTIONS

# %% [markdown]
# - 1) Go to the Chicago Data Portal's page for ["Crimes - 2001 to Preset"](https://data.cityofchicago.org/Public-Safety/Crimes-2001-to-Present/ijzp-q8t2).
#
# - 2) Click on the Export button on the top right and select CSV.
#     - Save the file to your Downloads folder instead of your repository. **The file is too big for a repository.**
#
#
#
# - 3) Wait for the full file to download.
#     - It is very large (over >1.7GB and may take several minutes to fully download.)
#
#
# - 4) Once the download is complete, change `RAW_FILE` variable below to match the filepath to the downloaded file.

# %% [markdown]
# ## 🚨 Set the correct `RAW_FILE` path

# %% [markdown]
# - The cell below will attempt to check your Downloads folder for any file with a name that contains "Crimes_-_2001_to_Present".
#     - If you know the file path already, you can skip the next cell and just manually set the RAW_FILE variable in the following code cell.

# %%
## Run the cell below to attempt to programmatically find your crime file
import os,glob

## Getting the home folder from environment variables
home_folder = os.environ['HOME']
# print("- Your Home Folder is: " + home_folder)

## Check for downloads folder
if 'Downloads' in os.listdir(home_folder):
    
    
    # Print the Downloads folder path
    dl_folder = os.path.abspath(os.path.join(home_folder,'Downloads'))
    print(f"- Your Downloads folder is '{dl_folder}/'\n")
    
    ## checking for crime files using glob
    crime_files = sorted(glob.glob(dl_folder+'/**/Crimes_-_2001_to_Present*',recursive=True))
    
    # If more than 
    if len(crime_files)==1:
        RAW_FILE = crime_files[0]
        
    elif len(crime_files)>1:
        print('[i] The following files were found:')
        
        for i, fname in enumerate(crime_files):
            print(f"\tcrime_files[{i}] = '{fname}'")
        print(f'\n- Please fill in the RAW_FILE variable in the code cell below with the correct filepath.')

else:
    print(f'[!] Could not programmatically find your downloads folder.')
    print('- Try using Finder (on Mac) or File Explorer (Windows) to navigate to your Downloads folder.')
# Out:
# - Your Downloads folder is 'C:\Users\jezep\Downloads/'

# %% [markdown]
# <span style="color:red"> **IF THE CODE ABOVE DID NOT FIND YOUR DOWNLOADED FILE, UNCOMMENT AND CHANGE THE `"YOUR FILEPATH HERE"` VARIABLE ONLY IN THE CELL BELOW**

# %%
## (Required) MAKE SURE TO CHANGE THIS VARIABLE TO MATCH YOUR LOCAL FILE NAME
##RAW_FILE = r"YOUR FILEPATH HERE")

# %% [markdown]
# <span style="color:red"> **DO NOT CHANGE ANYTHING IN THE CELL BELOW**

# %%
## DO NOT CHANGE THIS CELL
if RAW_FILE == r"YOUR FILEPATH HERE":
	raise Exception("You must update the RAW_FILE variable in the previous cell to match your local filepath.")
	
RAW_FILE
# Out:
# 'C:\\Users\\jezep\\Downloads\\Crimes_-_2001_to_Present.csv'

# %%
## (Optional) SET THE FOLDER FOR FINAL FILES
OUTPUT_FOLDER = 'Data/Chicago/'
os.makedirs(OUTPUT_FOLDER, exist_ok=True)

# %% [markdown]
# # 🔄 Full Workflow

# %% [markdown]
# - Now that your RAW_FILE variable is set either:
#     - On the toolbar, click on the Kernel menu > "Restart and Run All".
#     - OR click on this cell first, then on the toolbar click on the "Cell" menu > "Run All Below"

# %%
import pandas as pd

chicago_full = pd.read_csv(RAW_FILE)
chicago_full
# Out:
#                ID Case Number                    Date                   Block  \
# 0         5741943    HN549294  08/25/2007 09:22:18 AM      074XX N ROGERS AVE
# 1         1930689    HH109118  01/05/2002 09:24:00 PM          007XX E 103 ST
# 2        13203321    JG415333  09/06/2023 05:00:00 PM        002XX N Wells st
# 3        13210088    JG423627  08/31/2023 12:00:00 PM    023XX W JACKSON BLVD
# 4        13210004    JG422532  07/24/2023 09:45:00 PM    073XX S JEFFERY BLVD
# ...           ...         ...                     ...                     ...
# 7899121  13047495    JG229914  04/18/2023 08:00:00 AM    003XX N JEFFERSON ST
# 7899122  13168300    JG373901  08/07/2023 06:00:00 PM         0000X W 95TH ST
# 7899123  13114024    JG309527  06/20/2023 07:00:00 PM       031XX S AVERS AVE
# 7899124  13188860    JG398340  08/26/2023 12:00:00 AM  078XX S SOUTH SHORE DR
# 7899125  13126372    JG324067  07/01/2023 07:29:00 PM        005XX S WELLS ST
#
#          IUCR             Primary Type  \
# 0        0560                  ASSAULT
# 1        0820                    THEFT
# 2        1320          CRIMINAL DAMAGE
# 3        1153       DECEPTIVE PRACTICE
# 4        0281  CRIMINAL SEXUAL ASSAULT
# ...       ...                      ...
# 7899121  1154       DECEPTIVE PRACTICE
# 7899122  031A                  ROBBERY
# 7899123  0910      MOTOR VEHICLE THEFT
# 7899124  1320          CRIMINAL DAMAGE
# 7899125  1320          CRIMINAL DAMAGE
#
#                                      Description  \
# 0                                         SIMPLE
# 1                                 $500 AND UNDER
# 2                                     TO VEHICLE
# 3            FINANCIAL IDENTITY THEFT OVER $ 300
# 4                                 NON-AGGRAVATED
# ...                                          ...
# 7899121  FINANCIAL IDENTITY THEFT $300 AND UNDER
# 7899122                          ARMED - HANDGUN
# 7899123                               AUTOMOBILE
# 7899124                               TO VEHICLE
# 7899125                               TO VEHICLE
#
#                            Location Description  Arrest  Domestic  ...  Ward  \
# 0                                         OTHER   False     False  ...  49.0
# 1                                   GAS STATION    True     False  ...   NaN
# 2        PARKING LOT / GARAGE (NON RESIDENTIAL)   False     False  ...  42.0
# 3                                        STREET   False     False  ...  27.0
# 4                                     APARTMENT   False     False  ...   7.0
# ...                                         ...     ...       ...  ...   ...
# 7899121                               APARTMENT   False     False  ...  42.0
# 7899122                                SIDEWALK   False     False  ...   9.0
# 7899123                                  STREET   False     False  ...  22.0
# 7899124                                  STREET   False     False  ...   7.0
# 7899125                                  STREET   False      True  ...  34.0
#
#          Community Area  FBI Code  X Coordinate Y Coordinate  Year  \
# 0                   1.0       08A           NaN          NaN  2007
# 1                   NaN        06           NaN          NaN  2002
# 2                  32.0        14           NaN          NaN  2023
# 3                  28.0        11     1160870.0    1898642.0  2023
# 4                  43.0        02     1190812.0    1856743.0  2023
# ...                 ...       ...           ...          ...   ...
# 7899121            28.0        11     1172269.0    1902384.0  2023
# 7899122            49.0        03     1177527.0    1841973.0  2023
# 7899123            30.0        07     1151205.0    1883542.0  2023
# 7899124            46.0        14     1198338.0    1853426.0  2023
# 7899125            32.0        14     1174805.0    1897873.0  2023
#
#                      Updated On   Latitude  Longitude  \
# 0        08/17/2015 03:03:40 PM        NaN        NaN
# 1        02/04/2016 06:33:39 AM        NaN        NaN
# 2        09/14/2023 03:43:09 PM        NaN        NaN
# 3        09/16/2023 03:41:56 PM  41.877565 -87.684791
# 4        09/16/2023 03:41:56 PM  41.761919 -87.576209
# ...                         ...        ...        ...
# 7899121  08/19/2023 03:40:26 PM  41.887589 -87.642827
# 7899122  08/19/2023 03:40:26 PM  41.721698 -87.625345
# 7899123  08/19/2023 03:40:26 PM  41.836324 -87.720674
# 7899124  09/02/2023 03:41:45 PM  41.752631 -87.548737
# 7899125  08/19/2023 03:40:26 PM  41.875155 -87.633649
#
#                               Location
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3         (41.877565108, -87.68479102)
# 4          (41.7619185, -87.576209245)
# ...                                ...
# 7899121  (41.887589411, -87.642826595)
# 7899122   (41.72169837, -87.625345212)
# 7899123  (41.836323827, -87.720674149)
# 7899124  (41.752631346, -87.548737069)
# 7899125   (41.87515458, -87.633648765)
#
# [7899126 rows x 22 columns]

# %%
# this cell can take up to 1 min to run
date_format = "%m/%d/%Y %H:%M:%S %p"

chicago_full['Datetime'] = pd.to_datetime(chicago_full['Date'], format=date_format)
chicago_full = chicago_full.sort_values('Datetime')
chicago_full
# Out:
#                ID Case Number                    Date                 Block  \
# 3305731   6154338    HP242745  01/01/2001 01:00:00 PM    065XX S KEDZIE AVE
# 92767     1313213     G001554  01/01/2001 01:00:00 AM  071XX S LAFAYETTE AV
# 126526    1328315     G020979  01/01/2001 01:00:00 AM    067XX S JUSTINE ST
# 142563    1311626     G001009  01/01/2001 01:00:00 AM       023XX S TROY ST
# 77901     1313086     G004657  01/01/2001 01:00:00 PM      039XX N DRAKE AV
# ...           ...         ...                     ...                   ...
# 10531    13216534    JG431435  09/20/2023 12:00:00 AM       007XX E 84TH ST
# 10772    13223000    JG439107  09/20/2023 12:00:00 AM    085XX W HIGGINS RD
# 10665    13223275    JG439424  09/20/2023 12:00:00 AM   053XX W WARWICK AVE
# 10322    13216513    JG431390  09/20/2023 12:00:00 AM       034XX W 65TH ST
# 10809    13217098    JG432109  09/20/2023 12:00:00 AM    062XX N WHIPPLE ST
#
#          IUCR         Primary Type                    Description  \
# 3305731  0840                THEFT  FINANCIAL ID THEFT: OVER $300
# 92767    0460              BATTERY                         SIMPLE
# 126526   1130   DECEPTIVE PRACTICE       FRAUD OR CONFIDENCE GAME
# 142563   1320      CRIMINAL DAMAGE                     TO VEHICLE
# 77901    0810                THEFT                      OVER $500
# ...       ...                  ...                            ...
# 10531    1320      CRIMINAL DAMAGE                     TO VEHICLE
# 10772    1320      CRIMINAL DAMAGE                     TO VEHICLE
# 10665    0910  MOTOR VEHICLE THEFT                     AUTOMOBILE
# 10322    0920  MOTOR VEHICLE THEFT           ATTEMPT - AUTOMOBILE
# 10809    2820        OTHER OFFENSE               TELEPHONE THREAT
#
#            Location Description  Arrest  Domestic  ...  Community Area  \
# 3305731               RESIDENCE   False     False  ...            66.0
# 92767    VEHICLE NON-COMMERCIAL   False      True  ...             NaN
# 126526                RESIDENCE   False     False  ...             NaN
# 142563                   STREET   False     False  ...             NaN
# 77901                     OTHER   False     False  ...             NaN
# ...                         ...     ...       ...  ...             ...
# 10531                    STREET   False     False  ...            44.0
# 10772             HOTEL / MOTEL   False     False  ...            76.0
# 10665        RESIDENCE - GARAGE   False     False  ...            15.0
# 10322                    STREET   False     False  ...            66.0
# 10809                 RESIDENCE   False     False  ...             2.0
#
#          FBI Code  X Coordinate  Y Coordinate  Year              Updated On  \
# 3305731        06     1156214.0     1861165.0  2001  04/02/2008 01:05:33 AM
# 92767         08B     1177027.0     1857893.0  2001  08/17/2015 03:03:40 PM
# 126526         11     1167126.0     1859954.0  2001  08/17/2015 03:03:40 PM
# 142563         14     1155692.0     1888116.0  2001  08/17/2015 03:03:40 PM
# 77901          06     1151978.0     1926092.0  2001  08/17/2015 03:03:40 PM
# ...           ...           ...           ...   ...                     ...
# 10531          14     1182879.0     1849452.0  2023  09/27/2023 03:43:25 PM
# 10772          14     1118169.0     1938234.0  2023  09/27/2023 03:43:25 PM
# 10665          07           NaN           NaN  2023  09/27/2023 03:43:25 PM
# 10322          07     1154622.0     1861304.0  2023  09/27/2023 03:43:25 PM
# 10809         08A     1154889.0     1941210.0  2023  09/27/2023 03:43:25 PM
#
#           Latitude  Longitude                       Location  \
# 3305731  41.774819 -87.702896  (41.774818809, -87.702896431)
# 92767    41.765396 -87.626698  (41.765396066, -87.626697771)
# 126526   41.771269 -87.662929  (41.771269195, -87.662929135)
# 142563   41.848786 -87.704087  (41.848786421, -87.704086603)
# 77901    41.953070 -87.716716  (41.953070112, -87.716715611)
# ...            ...        ...                            ...
# 10531    41.742099 -87.605510  (41.742099153, -87.605510292)
# 10772    41.986989 -87.840746  (41.986989467, -87.840745861)
# 10665          NaN        NaN                            NaN
# 10322    41.775232 -87.708729  (41.775232124, -87.708728823)
# 10809    41.994497 -87.705607  (41.994496779, -87.705607304)
#
#                    Datetime
# 3305731 2001-01-01 01:00:00
# 92767   2001-01-01 01:00:00
# 126526  2001-01-01 01:00:00
# 142563  2001-01-01 01:00:00
# 77901   2001-01-01 01:00:00
# ...                     ...
# 10531   2023-09-20 12:00:00
# 10772   2023-09-20 12:00:00
# 10665   2023-09-20 12:00:00
# 10322   2023-09-20 12:00:00
# 10809   2023-09-20 12:00:00
#
# [7899126 rows x 23 columns]

# %% [markdown]
# ## Separate the Full Dataset by Years

# %%
chicago_full['Datetime'].dt.year
# Out:
# 3305731    2001
# 92767      2001
# 126526     2001
# 142563     2001
# 77901      2001
#            ...
# 10531      2023
# 10772      2023
# 10665      2023
# 10322      2023
# 10809      2023
# Name: Datetime, Length: 7899126, dtype: int32

# %%
# save the years for every crime
chicago_full["Year"] = chicago_full['Datetime'].dt.year.astype(str)
chicago_full["Year"].value_counts()
# Out:
# Year
# 2002    486807
# 2001    485888
# 2003    475985
# 2004    469423
# 2005    453774
# 2006    448178
# 2007    437090
# 2008    427184
# 2009    392827
# 2010    370517
# 2011    351993
# 2012    336322
# 2013    307540
# 2014    275792
# 2016    269834
# 2017    269109
# 2018    268912
# 2015    264793
# 2019    261352
# 2022    238947
# 2020    212220
# 2021    208870
# 2023    185769
# Name: count, dtype: int64

# %%
## Dropping unneeded columns to reduce file size
drop_cols = ["X Coordinate","Y Coordinate", "Community Area","FBI Code",
             "Case Number","Updated On",'Block','Location','IUCR']

# %%
# save final df
chicago_final = chicago_full.drop(columns=drop_cols)
chicago_final = chicago_final.set_index('Datetime')
chicago_final
# Out:
#                            ID                    Date         Primary Type  \
# Datetime
# 2001-01-01 01:00:00   6154338  01/01/2001 01:00:00 PM                THEFT
# 2001-01-01 01:00:00   1313213  01/01/2001 01:00:00 AM              BATTERY
# 2001-01-01 01:00:00   1328315  01/01/2001 01:00:00 AM   DECEPTIVE PRACTICE
# 2001-01-01 01:00:00   1311626  01/01/2001 01:00:00 AM      CRIMINAL DAMAGE
# 2001-01-01 01:00:00   1313086  01/01/2001 01:00:00 PM                THEFT
# ...                       ...                     ...                  ...
# 2023-09-20 12:00:00  13216534  09/20/2023 12:00:00 AM      CRIMINAL DAMAGE
# 2023-09-20 12:00:00  13223000  09/20/2023 12:00:00 AM      CRIMINAL DAMAGE
# 2023-09-20 12:00:00  13223275  09/20/2023 12:00:00 AM  MOTOR VEHICLE THEFT
# 2023-09-20 12:00:00  13216513  09/20/2023 12:00:00 AM  MOTOR VEHICLE THEFT
# 2023-09-20 12:00:00  13217098  09/20/2023 12:00:00 AM        OTHER OFFENSE
#
#                                        Description    Location Description  \
# Datetime
# 2001-01-01 01:00:00  FINANCIAL ID THEFT: OVER $300               RESIDENCE
# 2001-01-01 01:00:00                         SIMPLE  VEHICLE NON-COMMERCIAL
# 2001-01-01 01:00:00       FRAUD OR CONFIDENCE GAME               RESIDENCE
# 2001-01-01 01:00:00                     TO VEHICLE                  STREET
# 2001-01-01 01:00:00                      OVER $500                   OTHER
# ...                                            ...                     ...
# 2023-09-20 12:00:00                     TO VEHICLE                  STREET
# 2023-09-20 12:00:00                     TO VEHICLE           HOTEL / MOTEL
# 2023-09-20 12:00:00                     AUTOMOBILE      RESIDENCE - GARAGE
# 2023-09-20 12:00:00           ATTEMPT - AUTOMOBILE                  STREET
# 2023-09-20 12:00:00               TELEPHONE THREAT               RESIDENCE
#
#                      Arrest  Domestic  Beat  District  Ward  Year   Latitude  \
# Datetime
# 2001-01-01 01:00:00   False     False   831       8.0  15.0  2001  41.774819
# 2001-01-01 01:00:00   False      True   731       7.0   NaN  2001  41.765396
# 2001-01-01 01:00:00   False     False   725       7.0   NaN  2001  41.771269
# 2001-01-01 01:00:00   False     False  1033      10.0   NaN  2001  41.848786
# 2001-01-01 01:00:00   False     False  1732      17.0   NaN  2001  41.953070
# ...                     ...       ...   ...       ...   ...   ...        ...
# 2023-09-20 12:00:00   False     False   632       6.0   6.0  2023  41.742099
# 2023-09-20 12:00:00   False     False  1614      16.0  41.0  2023  41.986989
# 2023-09-20 12:00:00   False     False  1634      16.0  30.0  2023        NaN
# 2023-09-20 12:00:00   False     False   823       8.0  14.0  2023  41.775232
# 2023-09-20 12:00:00   False     False  2413      24.0  50.0  2023  41.994497
#
#                      Longitude
# Datetime
# 2001-01-01 01:00:00 -87.702896
# 2001-01-01 01:00:00 -87.626698
# 2001-01-01 01:00:00 -87.662929
# 2001-01-01 01:00:00 -87.704087
# 2001-01-01 01:00:00 -87.716716
# ...                        ...
# 2023-09-20 12:00:00 -87.605510
# 2023-09-20 12:00:00 -87.840746
# 2023-09-20 12:00:00        NaN
# 2023-09-20 12:00:00 -87.708729
# 2023-09-20 12:00:00 -87.705607
#
# [7899126 rows x 13 columns]

# %%
# unique # of year bins
year_bins = chicago_final['Year'].astype(str).unique()
year_bins
# Out:
# array(['2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008',
#        '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016',
#        '2017', '2018', '2019', '2020', '2021', '2022', '2023'],
#       dtype=object)

# %%
FINAL_DROP = ['Year']

# %%
## set save location 

os.makedirs(OUTPUT_FOLDER, exist_ok=True)
print(f"[i] Saving .csv's to {OUTPUT_FOLDER}")
## loop through years
for year in year_bins:
    
    ## save temp slices of dfs to save.
    temp_df = chicago_final.loc[year]
    temp_df = temp_df.sort_index()
    temp_df = temp_df.reset_index(drop=True)
    temp_df = temp_df.drop(columns=FINAL_DROP)

    # save as csv to output folder
    fname_temp = f"{OUTPUT_FOLDER}Chicago-Crime_{year}.csv"#.gz
    temp_df.to_csv(fname_temp,index=False)

    print(f"- Succesfully saved {fname_temp}")
# Out:
# [i] Saving .csv's to Data/Chicago/
# - Succesfully saved Data/Chicago/Chicago-Crime_2001.csv
# - Succesfully saved Data/Chicago/Chicago-Crime_2002.csv
# - Succesfully saved Data/Chicago/Chicago-Crime_2003.csv
# - Succesfully saved Data/Chicago/Chicago-Crime_2004.csv
# - Succesfully saved Data/Chicago/Chicago-Crime_2005.csv
# - Succesfully saved Data/Chicago/Chicago-Crime_2006.csv
# - Succesfully saved Data/Chicago/Chicago-Crime_2007.csv
# - Succesfully saved Data/Chicago/Chicago-Crime_2008.csv
# - Succesfully saved Data/Chicago/Chicago-Crime_2009.csv
# - Succesfully saved Data/Chicago/Chicago-Crime_2010.csv
# - Succesfully saved Data/Chicago/Chicago-Crime_2011.csv
# - Succesfully saved Data/Chicago/Chicago-Crime_2012.csv
# - Succesfully saved Data/Chicago/Chicago-Crime_2013.csv
# - Succesfully saved Data/Chicago/Chicago-Crime_2014.csv
# - Succesfully saved Data/Chicago/Chicago-Crime_2015.csv
# - Succesfully saved Data/Chicago/Chicago-Crime_2016.csv
# - Succesfully saved Data/Chicago/Chicago-Crime_2017.csv
# - Succesfully saved Data/Chicago/Chicago-Crime_2018.csv
# - Succesfully saved Data/Chicago/Chicago-Crime_2019.csv
# - Succesfully saved Data/Chicago/Chicago-Crime_2020.csv
# - Succesfully saved Data/Chicago/Chicago-Crime_2021.csv
# - Succesfully saved Data/Chicago/Chicago-Crime_2022.csv
# - Succesfully saved Data/Chicago/Chicago-Crime_2023.csv

# %%
saved_files = sorted(glob.glob(OUTPUT_FOLDER+'*.*csv'))
saved_files
# Out:
# ['Data/Chicago\\Chicago-Crime_2001.csv',
#  'Data/Chicago\\Chicago-Crime_2002.csv',
#  'Data/Chicago\\Chicago-Crime_2003.csv',
#  'Data/Chicago\\Chicago-Crime_2004.csv',
#  'Data/Chicago\\Chicago-Crime_2005.csv',
#  'Data/Chicago\\Chicago-Crime_2006.csv',
#  'Data/Chicago\\Chicago-Crime_2007.csv',
#  'Data/Chicago\\Chicago-Crime_2008.csv',
#  'Data/Chicago\\Chicago-Crime_2009.csv',
#  'Data/Chicago\\Chicago-Crime_2010.csv',
#  'Data/Chicago\\Chicago-Crime_2011.csv',
#  'Data/Chicago\\Chicago-Crime_2012.csv',
#  'Data/Chicago\\Chicago-Crime_2013.csv',
#  'Data/Chicago\\Chicago-Crime_2014.csv',
#  'Data/Chicago\\Chicago-Crime_2015.csv',
#  'Data/Chicago\\Chicago-Crime_2016.csv',
#  'Data/Chicago\\Chicago-Crime_2017.csv',
#  'Data/Chicago\\Chicago-Crime_2018.csv',
#  'Data/Chicago\\Chicago-Crime_2019.csv',
#  'Data/Chicago\\Chicago-Crime_2020.csv',
#  'Data/Chicago\\Chicago-Crime_2021.csv',
#  'Data/Chicago\\Chicago-Crime_2022.csv',
#  'Data/Chicago\\Chicago-Crime_2023.csv']

# %%
## create a README.txt for the zip files
readme = """Source URL: 
- https://data.cityofchicago.org/Public-Safety/Crimes-2001-to-Present/ijzp-q8t2
- Filtered for years 2000-Present.

Downloaded 07/18/2022
- Files are split into 1 year per file.

EXAMPLE USAGE:
>> import glob
>> import pandas as pd
>> folder = "Data/Chicago/"
>> crime_files = sorted(glob.glob(folder+"*.csv"))
>> df = pd.concat([pd.read_csv(f) for f in crime_files])
"""
print(readme)


with open(f"{OUTPUT_FOLDER}README.txt",'w') as f:
    f.write(readme)
# Out:
# Source URL:
# - https://data.cityofchicago.org/Public-Safety/Crimes-2001-to-Present/ijzp-q8t2
# - Filtered for years 2000-Present.
#
# Downloaded 07/18/2022
# - Files are split into 1 year per file.
#
# EXAMPLE USAGE:
# >> import glob
# >> import pandas as pd
# >> folder = "Data/Chicago/"
# >> crime_files = sorted(glob.glob(folder+"*.csv"))
# >> df = pd.concat([pd.read_csv(f) for f in crime_files])

# %% [markdown]
# ## Confirmation

# %% [markdown]
# - Follow the example usage above to test if your files were created successfully.

# %%
# get list of files from folder
crime_files = sorted(glob.glob(OUTPUT_FOLDER+"*.csv"))
df = pd.concat([pd.read_csv(f, nrows=5) for f in crime_files])
df
# Out:
#           ID                    Date        Primary Type  \
# 0    6154338  01/01/2001 01:00:00 PM               THEFT
# 1    1313213  01/01/2001 01:00:00 AM             BATTERY
# 2    1328315  01/01/2001 01:00:00 AM  DECEPTIVE PRACTICE
# 3    1311626  01/01/2001 01:00:00 AM     CRIMINAL DAMAGE
# 4    1313086  01/01/2001 01:00:00 PM               THEFT
# ..       ...                     ...                 ...
# 0   12938723  01/01/2023 01:00:00 AM       OTHER OFFENSE
# 1   12939725  01/01/2023 01:00:00 PM               THEFT
# 2   12939417  01/01/2023 01:00:00 AM     CRIMINAL DAMAGE
# 3   12939140  01/01/2023 01:00:00 AM               THEFT
# 4   12939172  01/01/2023 01:00:00 AM     CRIMINAL DAMAGE
#
#                       Description    Location Description  Arrest  Domestic  \
# 0   FINANCIAL ID THEFT: OVER $300               RESIDENCE   False     False
# 1                          SIMPLE  VEHICLE NON-COMMERCIAL   False      True
# 2        FRAUD OR CONFIDENCE GAME               RESIDENCE   False     False
# 3                      TO VEHICLE                  STREET   False     False
# 4                       OVER $500                   OTHER   False     False
# ..                            ...                     ...     ...       ...
# 0                TELEPHONE THREAT               APARTMENT   False      True
# 1                       OVER $500                  STREET   False     False
# 2                      TO VEHICLE                  STREET   False     False
# 3                  $500 AND UNDER           BAR OR TAVERN   False     False
# 4                     TO PROPERTY               APARTMENT   False     False
#
#     Beat  District  Ward   Latitude  Longitude
# 0    831       8.0  15.0  41.774819 -87.702896
# 1    731       7.0   NaN  41.765396 -87.626698
# 2    725       7.0   NaN  41.771269 -87.662929
# 3   1033      10.0   NaN  41.848786 -87.704087
# 4   1732      17.0   NaN  41.953070 -87.716716
# ..   ...       ...   ...        ...        ...
# 0   1012      10.0  24.0  41.854325 -87.730820
# 1   1214      12.0  27.0  41.889998 -87.656551
# 2    734       7.0  17.0  41.760449 -87.657918
# 3   1832      18.0  42.0  41.893542 -87.629702
# 4    412       4.0   8.0  41.740095 -87.578202
#
# [115 rows x 12 columns]

# %%
years = df['Date'].map(lambda x: x.split()[0].split('/')[-1])
years.value_counts().sort_index()
# Out:
# Date
# 2001    5
# 2002    5
# 2003    5
# 2004    5
# 2005    5
# 2006    5
# 2007    5
# 2008    5
# 2009    5
# 2010    5
# 2011    5
# 2012    5
# 2013    5
# 2014    5
# 2015    5
# 2016    5
# 2017    5
# 2018    5
# 2019    5
# 2020    5
# 2021    5
# 2022    5
# 2023    5
# Name: count, dtype: int64

# %% [markdown]
# ## Summary

# %% [markdown]
# - The chicago crime dataset has now been saved to your repository as csv files.
# - You should save your notebook, commit your work and push to GitHub using GitHub desktop.
